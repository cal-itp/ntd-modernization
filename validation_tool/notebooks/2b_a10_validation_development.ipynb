# %% [markdown]
# ### Prototyping automatic validation checks for NTD reporting data: form A-10
#
# Decided *not* to use Pandera to validate this form. Details in the section on Pandera below - it is more straightforward and customizable to write our own functions.
#
# This notebook first imports a csv of cleaned data, presumably submitted from the A10 form, from the NTD data files found on their website. The data was transformed in the notebook `2a_clean_format_data_a10.ipynb`.
#
# This notebook shows the development of the functions that are used in the executable file `a10_facilities_check.py`

# %%
import pandas as pd
import pandera as pa
import numpy as np

# %%
# data to validate -

df1 = pd.read_csv("../data/2021_a10_submitted_partialdata.csv", index_col = 0) # 2021
prior_yr = pd.read_csv("../data/2020_a10_submitted_partialdata.csv", index_col = 0) # 2020
df1.head(3)
# Out:
#                                               Agency         City State  \
# 0  Los Angeles County Metropolitan Transportation...  Los Angeles    CA
# 1  Los Angeles County Metropolitan Transportation...  Los Angeles    CA
# 2  Los Angeles County Metropolitan Transportation...  Los Angeles    CA
#
#                                    Organization Type  Reporter Type  year  \
# 0  Independent Public Agency or Authority of Tran...  Full Reporter  2021
# 1  Independent Public Agency or Authority of Tran...  Full Reporter  2021
# 2  Independent Public Agency or Authority of Tran...  Full Reporter  2021
#
#   Mode TOS             ownerships  Under 200 Vehicles  200 to 300 Vehicles  \
# 0   MB  DO                  Owned                 4.0                24.52
# 1   LR  DO                  Owned                17.0                 0.00
# 2   MB  PT  Leased by PT Provider                 3.0                 0.00
#
#    Over 300 Vehicles  Heavy Maintenance Facilities  Total Facilities
# 0               0.97                          1.94             31.43
# 1               0.00                          0.00             17.00
# 2               0.00                          0.00              3.00

# %%
print(df1.shape)
print(prior_yr.shape)
# Out:
# (325, 14)
# (439, 14)

# %% [markdown]
# ---
# ### Check validation rules with custom functions instead of Pandera
# We write 4 checks:

# %% [markdown]
# **1. Check that sum of total facilities for each agency, across all modes, is a whole number.** Historical error: "The total maintenance facilities {} you reported across all modes does not add up to a whole number."
#   * 6 errors in 2022
#   * 27 errors in 2021
#
#   Example 2021 issue:
# ```
# 3273011 | 91012 - Mountain Area Regional Transit Authority	| A10-032	| Stations and Maintenance Facilities - DO - (A-10)	Commuter Bus| Directly Operated	| The total maintenance facilities {1.23} you reported across all modes does not add up to a whole number.
# ```
#
# **2. Check that the sum of all total facilities is not zero.** Historical error: "You did not report any general purpose maintenance facility. For DO modes, you must report any maintenance facilities owned or leased by you. For PT modes, you must report any maintenance facilities owned or leased by you or your contractors."
# **3. Check whether total gen purpose facilities (all but heavy maintenance) is > 1.** If so throw error. Historical error: "You have reported {} general purpose maintenance facilities. Please confirm the subrecipient owns/leases multiple maintenance facilities or revise the number."

# %% [markdown]
# **4. Check that the total gen purpose facilities is same as prior year.** If not, throw error. Historical error: "Number of General Purpose Maintenance Facilities is {}, but was {} last report year."
# - rowbind 2021 and 2020
# - for each agency get all data. get last yr and this yr facility check

# %%
allyears = df1.append(prior_yr)
print(allyears.shape)
allyears.head()
# Out:
# (764, 14)
# /var/folders/3h/9n_2y6x178l41fsp4dg802f00000gn/T/ipykernel_63791/1471580887.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allyears = df1.append(prior_yr)
#                                               Agency         City State  \
# 0  Los Angeles County Metropolitan Transportation...  Los Angeles    CA
# 1  Los Angeles County Metropolitan Transportation...  Los Angeles    CA
# 2  Los Angeles County Metropolitan Transportation...  Los Angeles    CA
# 3  Los Angeles County Metropolitan Transportation...  Los Angeles    CA
# 4  Los Angeles County Metropolitan Transportation...  Los Angeles    CA
#
#                                    Organization Type  Reporter Type  year  \
# 0  Independent Public Agency or Authority of Tran...  Full Reporter  2021
# 1  Independent Public Agency or Authority of Tran...  Full Reporter  2021
# 2  Independent Public Agency or Authority of Tran...  Full Reporter  2021
# 3  Independent Public Agency or Authority of Tran...  Full Reporter  2021
# 4  Independent Public Agency or Authority of Tran...  Full Reporter  2021
#
#   Mode TOS             ownerships  Under 200 Vehicles  200 to 300 Vehicles  \
# 0   MB  DO                  Owned                 4.0                24.52
# 1   LR  DO                  Owned                17.0                 0.00
# 2   MB  PT  Leased by PT Provider                 3.0                 0.00
# 3   HR  DO                  Owned                 2.0                 0.00
# 4   RB  DO                  Owned                 0.0                 0.48
#
#    Over 300 Vehicles  Heavy Maintenance Facilities  Total Facilities
# 0               0.97                          1.94             31.43
# 1               0.00                          0.00             17.00
# 2               0.00                          0.00              3.00
# 3               0.00                          0.00              2.00
# 4               0.03                          0.06              0.57

# %%
import datetime

this_year = datetime.datetime.now().year
print(this_year)
last_yr = this_year - 1
last_yr



### for testing
agency = 'Antelope Valley Transit Authority'
this_year = 2021
allyears['year'].unique()

allyears[(allyears['Agency']==agency) & (allyears['year']==this_year)][['Under 200 Vehicles', 
                            '200 to 300 Vehicles',
                            'Over 300 Vehicles']].sum()

df = allyears.copy()
df[df['Agency']==agency]
# Out:
# 2023
#                                 Agency       City State  \
# 69   Antelope Valley Transit Authority  Lancaster    CA
# 70   Antelope Valley Transit Authority  Lancaster    CA
# 71   Antelope Valley Transit Authority  Lancaster    CA
# 111  Antelope Valley Transit Authority  Lancaster    CA
# 112  Antelope Valley Transit Authority  Lancaster    CA
# 114  Antelope Valley Transit Authority  Lancaster    CA
#
#                                      Organization Type  Reporter Type  year  \
# 69   Independent Public Agency or Authority of Tran...  Full Reporter  2021
# 70   Independent Public Agency or Authority of Tran...  Full Reporter  2021
# 71   Independent Public Agency or Authority of Tran...  Full Reporter  2021
# 111  Independent Public Agency or Authority of Tran...  Full Reporter  2020
# 112  Independent Public Agency or Authority of Tran...  Full Reporter  2020
# 114  Independent Public Agency or Authority of Tran...  Full Reporter  2020
#
#     Mode TOS              ownerships  Under 200 Vehicles  200 to 300 Vehicles  \
# 69    MB  PT  Owned by Public Agency                 0.7                  0.0
# 70    CB  PT  Owned by Public Agency                 0.3                  0.0
# 71    DR  PT   Leased by PT Provider                 1.0                  0.0
# 111   MB  PT  Owned by Public Agency                 0.7                  0.0
# 112   CB  PT  Owned by Public Agency                 0.3                  0.0
# 114   DR  PT   Leased by PT Provider                 1.0                  0.0
#
#      Over 300 Vehicles  Heavy Maintenance Facilities  Total Facilities
# 69                 0.0                           0.0               0.7
# 70                 0.0                           0.0               0.3
# 71                 0.0                           0.0               1.0
# 111                0.0                           0.0               0.7
# 112                0.0                           0.0               0.3
# 114                0.0                           0.0               1.0

# %%
import datetime

#for testing purposes
df = allyears.copy()

a10_agencies = df['Agency'].unique()
# this_year = datetime.datetime.now().year
this_year = 2021
last_year = this_year - 1

output = []


for agency in a10_agencies:
    # facilites are a whole number
    if len(df[df['Agency']==agency]) > 0:
        
        total_gen_fac = round(df[(df['Agency']==agency) & (df['year']==this_year)]
                          [['Under 200 Vehicles', 
                            '200 to 300 Vehicles',
                            'Over 300 Vehicles']].sum().sum())
                                          
        # check on whether there's >1 gen purpose fac and/or none reported
        if (round(total_gen_fac) <= 1) & (round(total_gen_fac) != 0):
            result = "pass"
            description = ""
            check_name = "Gen Purpose Facilities"
        elif round(total_gen_fac) > 1:
            result = "fail"
            description = "You reported > 1 general purpose facility. Please verify whether this is correct."
            check_name = "Multiple Gen Purpose Facilities"
        elif round(total_gen_fac) == 0:
            result = "fail"
            description = "You reported no general purpose facilities. Please verify whether this is correct."
            check_name = "Non-zero Gen Purpose Facilities"
        else:
            pass
        
        output_line = {"Organization": agency,
                       "name_of_check" : check_name,
                        "value_checked": f"Gen Purpose Facilities: {total_gen_fac}",
                        "check_status": result,
                        "Description": description}
        output.append(output_line)
        
        # Check whether data for both years is present, if so perform prior yr comparison.
        if (len(df[(df['Agency']==agency) & (df['year']==this_year)]) > 0) & (len(df[(df['Agency']==agency) & (df['year']==last_year)]) > 0): 
            
            last_yr_gen_fac = round(df[(df['Agency']==agency) & (df['year']==last_year)]
                                     [['Under 200 Vehicles', 
                                        '200 to 300 Vehicles',
                                        'Over 300 Vehicles']].sum().sum())
             
            if round(total_gen_fac) == round(last_yr_gen_fac):
                result = "pass"
                description = ""
                check_name = "Comparison to last yr: Gen Purpose Facilities"
            else:
                result = "fail"
                description = "Num. of general purpose facilities differs that last year - please verify or clarify."
                check_name = "Comparison to last yr: Gen Purpose Facilities"

            output_line = {"Organization": agency,
                           "name_of_check" : check_name,
                            "value_checked": f"{total_gen_fac} in {this_year}, {last_yr_gen_fac} in {last_year} (Gen Purpose Facilities)", 
                            "check_status": result,
                            "Description": description}
            output.append(output_line)

        else:
             pass
                              
    
    facility_checks = pd.DataFrame(output).sort_values(by="Organization")
# Out:
# total gen fac of 52 for Los Angeles County Metropolitan Transportation Authority , dba: Metro
# total gen fac of 9 for City and County of San Francisco, dba: San Francisco Municipal Transportation Agency
# total gen fac of 1 for California Vanpool Authority
# total gen fac of 6 for San Diego Metropolitan Transit System
# total gen fac of 5 for Orange County Transportation Authority
# total gen fac of 6 for Access Services
# total gen fac of 7 for Santa Clara Valley Transportation Authority
# total gen fac of 5 for San Francisco Bay Area Rapid Transit District
# total gen fac of 8 for Alameda-Contra Costa Transit District
# total gen fac of 0 for City of Los Angeles, dba: City of Los Angeles Department of Transportation
# total gen fac of 2 for Foothill Transit
# total gen fac of 4 for San Mateo County Transit District
# total gen fac of 3 for Sacramento Regional Transit District, dba: Sacramento RT
# total gen fac of 2 for Victor Valley Transit Authority
# total gen fac of 4 for Riverside Transit Agency
# total gen fac of 1 for Southern California Regional Rail Authority, dba: Metrolink
# total gen fac of 3 for North County Transit District
# total gen fac of 2 for City of Fresno, dba: Fresno Area Express
# total gen fac of 4 for Omnitrans
# total gen fac of 3 for Long Beach Transit
# total gen fac of 1 for City of Santa Monica, dba: Big Blue Bus
# total gen fac of 4 for Golden Gate Bridge, Highway and Transportation District
# total gen fac of 1 for Central Contra Costa Transit Authority, dba: COUNTY CONNECTION
# total gen fac of 1 for Peninsula Corridor Joint Powers Board, dba: Caltrain
# total gen fac of 1 for Golden Empire Transit District
# total gen fac of 2 for Antelope Valley Transit Authority
# total gen fac of 1 for City of Santa Clarita, dba: Santa Clarita Transit
# total gen fac of 2 for SunLine Transit Agency
# total gen fac of 1 for The Eastern Contra Costa Transit Authority, dba: Tri Delta Transit
# total gen fac of 1 for City of Torrance, dba: Torrance Transit System
# total gen fac of 2 for Monterey-Salinas Transit
# total gen fac of 2 for City of Montebello, dba: Montebello Bus Lines
# total gen fac of 2 for San Joaquin Regional Transit District
# total gen fac of 1 for Santa Cruz Metropolitan Transit District
# total gen fac of 1 for Santa Barbara Metropolitan Transit District
# total gen fac of 1 for Marin County Transit District
# total gen fac of 2 for City of Modesto , dba: Modesto Area Express
# total gen fac of 2 for Gold Coast Transit District
# total gen fac of 1 for Transit Joint Powers Authority for Merced County, dba: Merced The Bus
# total gen fac of 1 for Kings County Area Public Transit Agency
# total gen fac of 3 for Ventura County Transportation Commission
# total gen fac of 1 for County of Sonoma , dba: Sonoma County Transit
# total gen fac of 1 for Yolo County Transportation District
# total gen fac of 1 for City of Elk Grove
# total gen fac of 1 for Livermore / Amador Valley Transit Authority
# total gen fac of 1 for San Luis Obispo Regional Transit Authority
# total gen fac of 1 for City of Glendale
# total gen fac of 1 for Butte County Association of Governments
# total gen fac of 0 for Eastern Sierra Transit Authority
# total gen fac of 1 for City of Culver City, dba: Culver City Municipal Bus Lines
# total gen fac of 1 for City of Pasadena, dba: Pasadena Transit
# total gen fac of 1 for City of Visalia  , dba: Visalia Transit
# total gen fac of 5 for County of Placer, dba: Placer County Department of Public Works
# total gen fac of 1 for City of Fairfield, California, dba: Fairfield and Suisun Transit
# total gen fac of 2 for City of Norwalk , dba: Norwalk Transit System
# total gen fac of 1 for Yuba-Sutter Transit Authority
# total gen fac of 1 for City of Gardena, dba: GTrans
# total gen fac of 1 for Anaheim Transportation Network
# total gen fac of 2 for Stanislaus County , dba: Stanislaus Regional Transit
# total gen fac of 1 for Palos Verdes Peninsula Transit Authority
# total gen fac of 0 for Mendocino Transit Authority
# total gen fac of 2 for Pomona Valley Transportation Authority
# total gen fac of 2 for City of Santa Rosa
# total gen fac of 0 for Tulare County Area Transit
# total gen fac of 1 for Western Contra Costa Transit Authority
# total gen fac of 1 for City of Roseville, dba: Roseville Transit
# total gen fac of 0 for Lake Transit Authority
# total gen fac of 1 for Altamont Corridor Express
# total gen fac of 1 for University of California, Davis, dba: ASUCD-Unitrans
# total gen fac of 1 for City of Redondo Beach, dba: Beach Cities Transit
# total gen fac of 1 for Redding Area Bus Authority
# total gen fac of 1 for City of Huntington Park
# total gen fac of 2 for City of Santa Maria, dba: Santa Maria Area Transit
# total gen fac of 1 for City of Claremont, dba: Claremont Dial-a-Ride
# total gen fac of 1 for City of Camarillo, dba: Camarillo Area Transit
# total gen fac of 1 for City of Madera
# total gen fac of 1 for City of Laguna Beach, dba: Laguna Beach Transit
# total gen fac of 1 for City of Thousand Oaks, dba: Thousand Oaks Transit
# total gen fac of 2 for City of Burbank
# total gen fac of 1 for City of Union City, dba: Union City Transit
# total gen fac of 0 for Amador Regional Transit System
# total gen fac of 1 for City of Simi Valley, dba: Simi Valley Transit
# total gen fac of 1 for Imperial County Transportation Commission
# total gen fac of 2 for Los Angeles County Department of Public Works - East L.A.
# total gen fac of 0 for Mountain Area Regional Transit Authority, dba: Mountain Transit
# total gen fac of 1 for El Dorado County Transit Authority
# total gen fac of 1 for City of Cerritos
# total gen fac of 1 for City of San Luis Obispo
# total gen fac of 1 for City of Riverside
# total gen fac of 1 for City of Calabasas
# total gen fac of 1 for City of Vacaville
# total gen fac of 1 for City of Alhambra, dba: Alhambra Community Transit  aka ACT
# total gen fac of 1 for City of Porterville, dba: Porterville Transit
# total gen fac of 0 for Humboldt Transit Authority
# total gen fac of 1 for City of Arcadia, dba: Arcadia Transit
# total gen fac of 0 for Tehama County
# total gen fac of 1 for City of South Gate
# total gen fac of 1 for City of Tracy
# total gen fac of 0 for County of Sacramento Municipal Services Agency Department of Transportation
# total gen fac of 0 for Morongo Basin Transit Authority
# total gen fac of 1 for City of Lakewood , dba: DASH Transit
# total gen fac of 1 for City of Petaluma, dba: Petaluma Transit
# total gen fac of 2 for City of El Monte , dba: City of El Monte Transportation Division
# total gen fac of 1 for City of Turlock, dba: Turlock Transit
# total gen fac of 1 for City of Commerce, dba: City of Commerce Municipal Buslines
# total gen fac of 0 for City of Dixon
# total gen fac of 1 for City of Whittier
# total gen fac of 1 for Los Angeles County Department of Public Works - Whittier
# total gen fac of 1 for City of Lompoc, dba: City of Lompoc - Lompoc Transit
# total gen fac of 1 for City of Tulare, dba: Tulare Intermodal Express
# total gen fac of 0 for San Benito County LTA
# total gen fac of 1 for City of Lodi, dba: GrapeLine
# total gen fac of 100 for City of Corona
# total gen fac of 1 for City of Bell
# total gen fac of 1 for Santa Barbara County Association of Governments
# total gen fac of 3 for Sonoma-Marin Area Rail Transit District
# total gen fac of 0 for Mariposa County Transit
# total gen fac of 1 for City of Inglewood
# total gen fac of 1 for City of Baldwin Park, dba: Baldwin Park Transit
# total gen fac of 1 for City of Delano
# total gen fac of 1 for City of West Covina
# total gen fac of 0 for Madera County
# total gen fac of 1 for Paratransit, Inc.
# total gen fac of 0 for County of Siskiyou, dba: Siskiyou County Transit
# total gen fac of 2 for City of Compton  , dba: Compton Renaissance Transit Service
# total gen fac of 1 for City of Rosemead
# total gen fac of 1 for City of West Hollywood
# total gen fac of 0 for City of Corcoran
# total gen fac of 0 for Colusa County Transit Agency
# total gen fac of 0 for Redwood Coast Transit Authority
# total gen fac of 0 for Lassen Transit Service Agency
# total gen fac of 0 for Town of Truckee
# total gen fac of 1 for City of Cudahy
# total gen fac of 1 for Los Angeles County Department of Public Works - South Whittier
# total gen fac of 0 for City of Dinuba
# total gen fac of 1 for City of Bell Gardens
# total gen fac of 2 for San Francisco Bay Area Water Emergency Transportation Authority, dba: San Francisco Bay Ferry
# total gen fac of 0 for Trinity County
# total gen fac of 1 for City of Beverly Hills
# total gen fac of 1 for City of Lynwood
# total gen fac of 0 for City of Ridgecrest, dba: Ridgerunner
# total gen fac of 1 for City of Monrovia
# total gen fac of 1 for City of La Mirada , dba: La Mirada Transit
# total gen fac of 2 for City of Monterey Park
# total gen fac of 1 for City of Moorpark
# total gen fac of 2 for City of Avalon
# total gen fac of 0 for Glenn Transit Service
# total gen fac of 1 for City of Bellflower
# total gen fac of 0 for City of Rio Vista, dba: Rio Vista Delta Breeze
# total gen fac of 0 for City of Taft
# total gen fac of 1 for County of Ventura
# total gen fac of 1 for City of Agoura Hills
# total gen fac of 1 for City of Covina
# total gen fac of 1 for Los Angeles County Dept. of Public Works - Willowbrook et al.
# total gen fac of 1 for City of Malibu
# total gen fac of 1 for City of Santa Fe Springs
# total gen fac of 0 for City of California City
# total gen fac of 1 for City of Davis, dba: Davis Community Transit
# total gen fac of 1 for Los Angeles County Dept. of Public Works - Florence-Firestone
# total gen fac of 0 for City of Ojai
# total gen fac of 1 for Morongo Band of Mission Indians
# total gen fac of 1 for City of Manhattan Beach , dba: City of Manhattan Beach Dial-A-Ride
# total gen fac of 1 for Los Angeles County Dept. of Public Works - King Medical Center Shuttle Service
# total gen fac of 1 for Los Angeles County Dept. of Public Works - Willowbrook Shuttle
# total gen fac of 0 for City of Escalon
# total gen fac of 1 for Los Angeles County Dept. of Public Works - Lennox Shuttle
# total gen fac of 1 for Los Angeles County Dept. of Public Works - Athens Shuttle Service
# total gen fac of 1 for Los Angeles County Department of Public Works - East Valinda
# total gen fac of 1 for Chemehuevi Indian Tribe
# total gen fac of 1 for Los Angeles County Department of Public Works - Avocado Heights
# total gen fac of 1 for City of Pico Rivera
# total gen fac of 0 for Los Angeles County Metropolitan Transportation Authority, dba: Metro
# total gen fac of 0 for Access Services
# total gen fac of 0 for City and County of San Francisco, dba: San Francisco Municipal Transportation Agency (MUNI)
# total gen fac of 0 for California Vanpool Authority, dba: CalVans
# total gen fac of 0 for Alameda-Contra Costa Transit District, dba: AC Transit
# total gen fac of 0 for San Diego Association of Governments
# total gen fac of 0 for San Mateo County Transit District, dba: SamTrans
# total gen fac of 0 for City of Los Angeles, dba: Los Angeles Department of Transportation
# total gen fac of 0 for Metropolitan Transportation Commission
# total gen fac of 0 for San Joaquin Council
# total gen fac of 0 for Riverside County Transportation Commission
# total gen fac of 0 for Fresno County Rural Transit Agency
# total gen fac of 0 for County of Sonoma, dba: Sonoma County Transit
# total gen fac of 0 for City of Modesto, dba: Modesto Area Express
# total gen fac of 0 for San Bernardino County Transportation Authority
# total gen fac of 0 for Yolo County Transportation District, dba: Yolobus
# total gen fac of 0 for City of Elk Grove, dba: e-tran
# total gen fac of 0 for Napa Valley Transportation Authority
# total gen fac of 0 for City of Culver City, dba: Culver City Municipal Bus Lines (CityBus)
# total gen fac of 0 for City of Visalia, dba: Visalia Transit
# total gen fac of 0 for Kern Regional Transit
# total gen fac of 0 for Solano County Transit
# total gen fac of 0 for University of California, Davis, dba: Unitrans
# total gen fac of 0 for City of Norwalk, dba: Norwalk Transit System
# total gen fac of 0 for Stanislaus County, dba: Stanislaus Regional Transit
# total gen fac of 0 for Easy Lift Transportation
# total gen fac of 0 for Tuolumne County Transit
# total gen fac of 0 for City of Vacaville, dba: City Coach
# total gen fac of 0 for City of San Luis Obispo, dba: SLO Transit
# total gen fac of 0 for City of Downey
# total gen fac of 0 for Nevada County Transit Services
# total gen fac of 0 for City of Alhambra
# total gen fac of 0 for City of Carson
# total gen fac of 0 for San Luis Obispo Council of Governments
# total gen fac of 0 for City of Glendora
# total gen fac of 0 for City of Tracy, dba: TRACER
# total gen fac of 0 for City of Porterville
# total gen fac of 0 for City of El Monte, dba: City of El Monte Transportation Division
# total gen fac of 0 for City of Lakewood, dba: DASH Transit
# total gen fac of 0 for Yosemite Area Regional Transportation System
# total gen fac of 0 for City of Lompoc, dba: Lompoc Transit
# total gen fac of 0 for City of Shafter, dba: Shafter Dial-A-Ride
# total gen fac of 0 for City of Dixon, dba: Readi-Ride
# total gen fac of 0 for City of Eureka, dba: Eureka Transit Service
# total gen fac of 0 for Mariposa County Transit, dba: Mari-Go
# total gen fac of 0 for Madera County, dba: Madera County Connection Transit
# total gen fac of 0 for City of La Mirada, dba: La Mirada Transit
# total gen fac of 0 for City of Compton, dba: Compton Renaissance Transit Service
# total gen fac of 0 for City of Corcoran, dba: Corcoran Area Transit
# total gen fac of 0 for City of Azusa
# total gen fac of 0 for Calaveras Transit Agency
# total gen fac of 0 for City of Arvin
# total gen fac of 0 for Palo Verde Valley Transit Agency
# total gen fac of 0 for City of Maywood
# total gen fac of 0 for City of Manteca, dba: Manteca Transit
# total gen fac of 0 for City of Artesia
# total gen fac of 0 for City of Auburn
# total gen fac of 0 for City of Solvang
# total gen fac of 0 for Sierra County Transportation Commission
# total gen fac of 0 for City of Manhattan Beach
# total gen fac of 0 for Yurok Tribe
# total gen fac of 0 for City of Woodlake
# total gen fac of 0 for City of South Pasadena
# total gen fac of 0 for Blue Lake Rancheria
# total gen fac of 0 for City of Arcata
# total gen fac of 0 for City of Taft, dba: Taft Area Transit
# total gen fac of 0 for Plumas County Transportation Commission
# total gen fac of 0 for City of Atascadero, dba: Atascadero Dial-a-Ride
# total gen fac of 0 for City of Guadalupe
# total gen fac of 0 for Modoc Transportation Agency
# total gen fac of 0 for City of Chowchilla, dba: Chowchilla Area Transit
# total gen fac of 0 for North Fork Rancheria of Mono Indians of California
# total gen fac of 0 for City of Tehachapi
# total gen fac of 0 for City of Lawndale
# total gen fac of 0 for Wasco, City of
# total gen fac of 0 for Alpine County Local Transportation Commission
# total gen fac of 0 for Elk Valley Rancheria
# total gen fac of 0 for Susanville Indian Rancheria
# total gen fac of 0 for City of Escalon, dba: eTrans
# total gen fac of 0 for City of Needles, dba: Needles Area Transit
# total gen fac of 0 for City of McFarland
# total gen fac of 0 for City of Sierra Madre
# total gen fac of 0 for City of La Habra Heights
# total gen fac of 0 for City of San Fernando
# total gen fac of 0 for City of El Segundo
# total gen fac of 0 for Playa Vista Parks and Landscape Corp.
# total gen fac of 0 for City of Hawaiian Gardens
# total gen fac of 0 for City of South El Monte

# %%
print(facility_checks.shape)
facility_checks.head(20)
# Out:
# (394, 5)
#                                           Organization  \
# 307                                    Access Services
# 7                                    Access Services
# 12               Alameda-Contra Costa Transit District
# 310  Alameda-Contra Costa Transit District, dba: AC...
# 381      Alpine County Local Transportation Commission
# 119                          Altamont Corridor Express
# 120                          Altamont Corridor Express
# 143                     Amador Regional Transit System
# 144                     Amador Regional Transit System
# 100                     Anaheim Transportation Network
# 101                     Anaheim Transportation Network
# 43                   Antelope Valley Transit Authority
# 44                   Antelope Valley Transit Authority
# 369                                Blue Lake Rancheria
# 83             Butte County Association of Governments
# 84             Butte County Association of Governments
# 356                           Calaveras Transit Agency
# 2                         California Vanpool Authority
# 309         California Vanpool Authority, dba: CalVans
# 37   Central Contra Costa Transit Authority, dba: C...
#
#                                      name_of_check  \
# 307                Non-zero Gen Purpose Facilities
# 7                  Multiple Gen Purpose Facilities
# 12                 Multiple Gen Purpose Facilities
# 310                Non-zero Gen Purpose Facilities
# 381                Non-zero Gen Purpose Facilities
# 119                         Gen Purpose Facilities
# 120  Comparison to last yr: Gen Purpose Facilities
# 143                Non-zero Gen Purpose Facilities
# 144  Comparison to last yr: Gen Purpose Facilities
# 100                         Gen Purpose Facilities
# 101  Comparison to last yr: Gen Purpose Facilities
# 43                 Multiple Gen Purpose Facilities
# 44   Comparison to last yr: Gen Purpose Facilities
# 369                Non-zero Gen Purpose Facilities
# 83                          Gen Purpose Facilities
# 84   Comparison to last yr: Gen Purpose Facilities
# 356                Non-zero Gen Purpose Facilities
# 2                           Gen Purpose Facilities
# 309                Non-zero Gen Purpose Facilities
# 37                          Gen Purpose Facilities
#
#                                      value_checked check_status  \
# 307                      Gen Purpose Facilities: 0         fail
# 7                        Gen Purpose Facilities: 6         fail
# 12                       Gen Purpose Facilities: 8         fail
# 310                      Gen Purpose Facilities: 0         fail
# 381                      Gen Purpose Facilities: 0         fail
# 119                      Gen Purpose Facilities: 1         pass
# 120  1 in 2021, 1 in 2020 (Gen Purpose Facilities)         pass
# 143                      Gen Purpose Facilities: 0         fail
# 144  0 in 2021, 0 in 2020 (Gen Purpose Facilities)         pass
# 100                      Gen Purpose Facilities: 1         pass
# 101  1 in 2021, 1 in 2020 (Gen Purpose Facilities)         pass
# 43                       Gen Purpose Facilities: 2         fail
# 44   2 in 2021, 2 in 2020 (Gen Purpose Facilities)         pass
# 369                      Gen Purpose Facilities: 0         fail
# 83                       Gen Purpose Facilities: 1         pass
# 84   1 in 2021, 1 in 2020 (Gen Purpose Facilities)         pass
# 356                      Gen Purpose Facilities: 0         fail
# 2                        Gen Purpose Facilities: 1         pass
# 309                      Gen Purpose Facilities: 0         fail
# 37                       Gen Purpose Facilities: 1         pass
#
#                                            Description
# 307  You reported no general purpose facilities. Pl...
# 7    You reported > 1 general purpose facility. Ple...
# 12   You reported > 1 general purpose facility. Ple...
# 310  You reported no general purpose facilities. Pl...
# 381  You reported no general purpose facilities. Pl...
# 119
# 120
# 143  You reported no general purpose facilities. Pl...
# 144
# 100
# 101
# 43   You reported > 1 general purpose facility. Ple...
# 44
# 369  You reported no general purpose facilities. Pl...
# 83
# 84
# 356  You reported no general purpose facilities. Pl...
# 2
# 309  You reported no general purpose facilities. Pl...
# 37

# %%
facility_checks.to_csv("../data/test.csv", index=False)

# %% [markdown]
# Table to make:
# `Organization | name_of_check | value_checked | check_status | Description`

# %%
a10_agencies = df['Agency'].unique()

output = []
for agency in a10_agencies:

    ##Total facilities
    if len(df[df['Agency']==agency]) > 0:
        total_fac = round(df[(df['Agency']==agency) & ((df['year']==this_year))]['Total Facilities'].sum())
        
        # whole number check
        if total_fac % 1 == 0:
            result = "pass"
            description = ""
            check_name = "Whole Number Facilities"
        else:
            result = "fail"
            description = "The reported total facilities do not add up to a whole number. Please explain."
            check_name = "Whole Number Facilities"
        
        output_line = {"Organization": agency,
                       "name_of_check" : check_name,
                           "value_checked": f"Total Facilities: {total_fac}",
                           "check_status": result,
                          "Description": description}
        output.append(output_line)
        
        # Non-zero check
        if total_fac != 0:
            result = "pass"
            description = ""
            check_name = "Non-zero Facilities"
        else:
            result = "fail"
            description = "There are no reported facilities. Please verify or explain."
            check_name = "Non-zero Facilities"
        
        output_line = {"Organization": agency,
                       "name_of_check" : check_name,
                        "value_checked": f"Total Facilities: {total_fac}",
                        "check_status": result,
                        "Description": description}
        output.append(output_line)
        
        ## General purpose facilities (all except "heavy maintenance")
        total_gen_fac = round(df[(df['Agency']==agency) & (df['year']==this_year)]
                          [['Under 200 Vehicles', 
                            '200 to 300 Vehicles',
                            'Over 300 Vehicles']].sum().sum())
                                          
        # check on whether there's >1 gen purpose fac and/or none reported
        if (round(total_gen_fac) <= 1) & (round(total_gen_fac) != 0):
            result = "pass"
            description = ""
            check_name = "Gen Purpose Facilities"
        elif round(total_gen_fac) > 1:
            result = "fail"
            description = "You reported > 1 general purpose facility. Please verify whether this is correct."
            check_name = "Multiple Gen Purpose Facilities"
        elif round(total_gen_fac) == 0:
            result = "fail"
            description = "You reported no general purpose facilities. Please verify whether this is correct."
            check_name = "Non-zero Gen Purpose Facilities"
        else:
            pass
        
        output_line = {"Organization": agency,
                       "name_of_check" : check_name,
                        "value_checked": f"Gen Purpose Facilities: {total_gen_fac}",
                        "check_status": result,
                        "Description": description}
        output.append(output_line)
        
        # Check whether data for both years is present, if so perform prior yr comparison.
        if (len(df[(df['Agency']==agency) & (df['year']==this_year)]) > 0) & (len(df[(df['Agency']==agency) & (df['year']==last_year)]) > 0): 
            
            last_yr_gen_fac = round(df[(df['Agency']==agency) & (df['year']==last_year)]
                                     [['Under 200 Vehicles', 
                                        '200 to 300 Vehicles',
                                        'Over 300 Vehicles']].sum().sum())
             
            if round(total_gen_fac) == round(last_yr_gen_fac):
                result = "pass"
                description = ""
                check_name = "Comparison to last yr: Gen Purpose Facilities"
            else:
                result = "fail"
                description = "Num. of general purpose facilities differs that last year - please verify or clarify."
                check_name = "Comparison to last yr: Gen Purpose Facilities"

            output_line = {"Organization": agency,
                           "name_of_check" : check_name,
                            "value_checked": f"{total_gen_fac} in {this_year}, {last_yr_gen_fac} in {last_year} (Gen Purpose Facilities)", 
                            "check_status": result,
                            "Description": description}
            output.append(output_line)

        else:
             pass
    
    facility_checks = pd.DataFrame(output).sort_values(by="Organization")

# %%
print(facility_checks.shape)
facility_checks.head(20)
# Out:
# (912, 5)
#                                           Organization  \
# 652                                    Access Services
# 653                                    Access Services
# 651                                    Access Services
# 19                                   Access Services
# 18                                   Access Services
# 17                                   Access Services
# 29               Alameda-Contra Costa Transit District
# 28               Alameda-Contra Costa Transit District
# 30               Alameda-Contra Costa Transit District
# 660  Alameda-Contra Costa Transit District, dba: AC...
# 662  Alameda-Contra Costa Transit District, dba: AC...
# 661  Alameda-Contra Costa Transit District, dba: AC...
# 874      Alpine County Local Transportation Commission
# 873      Alpine County Local Transportation Commission
# 875      Alpine County Local Transportation Commission
# 254                          Altamont Corridor Express
# 255                          Altamont Corridor Express
# 253                          Altamont Corridor Express
# 256                          Altamont Corridor Express
# 303                     Amador Regional Transit System
#
#                                      name_of_check  \
# 652                            Non-zero Facilities
# 653                Non-zero Gen Purpose Facilities
# 651                        Whole Number Facilities
# 19                 Multiple Gen Purpose Facilities
# 18                             Non-zero Facilities
# 17                         Whole Number Facilities
# 29                             Non-zero Facilities
# 28                         Whole Number Facilities
# 30                 Multiple Gen Purpose Facilities
# 660                        Whole Number Facilities
# 662                Non-zero Gen Purpose Facilities
# 661                            Non-zero Facilities
# 874                            Non-zero Facilities
# 873                        Whole Number Facilities
# 875                Non-zero Gen Purpose Facilities
# 254                            Non-zero Facilities
# 255                         Gen Purpose Facilities
# 253                        Whole Number Facilities
# 256  Comparison to last yr: Gen Purpose Facilities
# 303                        Whole Number Facilities
#
#                                      value_checked check_status  \
# 652                            Total Facilities: 6         pass
# 653                      Gen Purpose Facilities: 0         fail
# 651                            Total Facilities: 6         pass
# 19                       Gen Purpose Facilities: 6         fail
# 18                             Total Facilities: 6         pass
# 17                             Total Facilities: 6         pass
# 29                             Total Facilities: 9         pass
# 28                             Total Facilities: 9         pass
# 30                       Gen Purpose Facilities: 8         fail
# 660                            Total Facilities: 9         pass
# 662                      Gen Purpose Facilities: 0         fail
# 661                            Total Facilities: 9         pass
# 874                            Total Facilities: 0         fail
# 873                            Total Facilities: 0         pass
# 875                      Gen Purpose Facilities: 0         fail
# 254                            Total Facilities: 2         pass
# 255                      Gen Purpose Facilities: 1         pass
# 253                            Total Facilities: 2         pass
# 256  1 in 2021, 1 in 2020 (Gen Purpose Facilities)         pass
# 303                            Total Facilities: 2         pass
#
#                                            Description
# 652
# 653  You reported no general purpose facilities. Pl...
# 651
# 19   You reported > 1 general purpose facility. Ple...
# 18
# 17
# 29
# 28
# 30   You reported > 1 general purpose facility. Ple...
# 660
# 662  You reported no general purpose facilities. Pl...
# 661
# 874  There are no reported facilities. Please explain.
# 873
# 875  You reported no general purpose facilities. Pl...
# 254
# 255
# 253
# 256
# 303

# %% [markdown]
# #### Checking against prior year submissions.
# NEXT TO DO:
# Make a `year` column and add another row for prior year, then compare against years in the `group by` checks.
# We will have to build adding on the prior year's data for each agency, into the data pipeline. Possibly:
# * agency submits a form
# * we format the form, then row bind the prior year's form to it from a table that has all agency info from 2022 for each form. (must have identical table schema)

# %% [markdown]
# ### Pandera testing.
# https://github.com/unionai-oss/pandera
# (this part included just to show how we checked out Pandera and then decided not to use it)

# %%
### Create schema - this is what will define what the data table needs to conform to - and hold all validation checks.
# We can infer a template from the starting data.


facilities_a10_schema = pa.infer_schema(df).to_script()
print(facilities_a10_schema)
# Out:
# from pandera import DataFrameSchema, Column, Check, Index, MultiIndex
#
# schema = DataFrameSchema(
#     columns={
#         "Agency": Column(
#             dtype="object",
#             checks=None,
#             nullable=False,
#             unique=False,
#             coerce=False,
#             required=True,
#             regex=False,
#             description=None,
#             title=None,
#         ),
#         "City": Column(
#             dtype="object",
#             checks=None,
#             nullable=False,
#             unique=False,
#             coerce=False,
#             required=True,
#             regex=False,
#             description=None,
#             title=None,
#         ),
#         "State": Column(
#             dtype="object",
#             checks=None,
#             nullable=False,
#             unique=False,
#             coerce=False,
#             required=True,
#             regex=False,
#             description=None,
#             title=None,
#         ),
#         "Organization Type": Column(
#             dtype="object",
#             checks=None,
#             nullable=False,
#             unique=False,
#             coerce=False,
#             required=True,
#             regex=False,
#             description=None,
#             title=None,
#         ),
#         "Reporter Type": Column(
#             dtype="object",
#             checks=None,
#             nullable=False,
#             unique=False,
#             coerce=False,
#             required=True,
#             regex=False,
#             description=None,
#             title=None,
#         ),
#         "Mode": Column(
#             dtype="object",
#             checks=None,
#             nullable=False,
#             unique=False,
#             coerce=False,
#             required=True,
#             regex=False,
#             description=None,
#             title=None,
#         ),
#         "TOS": Column(
#             dtype="object",
#             checks=None,
#             nullable=False,
#             unique=False,
#             coerce=False,
#             required=True,
#             regex=False,
#             description=None,
#             title=None,
#         ),
#         "ownerships": Column(
#             dtype="object",
#             checks=None,
#             nullable=False,
#             unique=False,
#             coerce=False,
#             required=True,
#             regex=False,
#             description=None,
#             title=None,
#         ),
#         "Under 200 Vehicles": Column(
#             dtype="float64",
#             checks=[
#                 Check.greater_than_or_equal_to(min_value=0.0),
#                 Check.less_than_or_equal_to(max_value=65.0),
#             ],
#             nullable=False,
#             unique=False,
#             coerce=False,
#             required=True,
#             regex=False,
#             description=None,
#             title=None,
#         ),
#         "200 to 300 Vehicles": Column(
#             dtype="float64",
#             checks=[
#                 Check.greater_than_or_equal_to(min_value=0.0),
#                 Check.less_than_or_equal_to(max_value=24.52),
#             ],
#             nullable=False,
#             unique=False,
#             coerce=False,
#             required=True,
#             regex=False,
#             description=None,
#             title=None,
#         ),
#         "Over 300 Vehicles": Column(
#             dtype="float64",
#             checks=[
#                 Check.greater_than_or_equal_to(min_value=0.0),
#                 Check.less_than_or_equal_to(max_value=0.97),
#             ],
#             nullable=False,
#             unique=False,
#             coerce=False,
#             required=True,
#             regex=False,
#             description=None,
#             title=None,
#         ),
#         "Heavy Maintenance Facilities": Column(
#             dtype="float64",
#             checks=[
#                 Check.greater_than_or_equal_to(min_value=0.0),
#                 Check.less_than_or_equal_to(max_value=1.94),
#             ],
#             nullable=False,
#             unique=False,
#             coerce=False,
#             required=True,
#             regex=False,
#             description=None,
#             title=None,
#         ),
#         "Total Facilities": Column(
#             dtype="float64",
#             checks=[
#                 Check.greater_than_or_equal_to(min_value=0.03),
#                 Check.less_than_or_equal_to(max_value=65.0),
#             ],
#             nullable=False,
#             unique=False,
#             coerce=False,
#             required=True,
#             regex=False,
#             description=None,
#             title=None,
#         ),
#     },
#     checks=None,
#     index=Index(
#         dtype="int64",
#         checks=[
#             Check.greater_than_or_equal_to(min_value=0.0),
#             Check.less_than_or_equal_to(max_value=324.0),
#         ],
#         nullable=False,
#         coerce=False,
#         name=None,
#         description=None,
#         title=None,
#     ),
#     dtype=None,
#     coerce=True,
#     strict=False,
#     name=None,
#     ordered=False,
#     unique=None,
#     report_duplicates="all",
#     unique_column_names=False,
#     add_missing_columns=False,
#     title=None,
#     description=None,
# )

# %% [markdown]
# Copied and pasted the output above into a file called `a10_inferred_schema`  in a folder I made here called `schemas`.
#   Now will try to validate it against its own data.

# %%
from schemas.a10_inferred_schema import schema
try:
    schema.validate(df, lazy=True)
except pa.errors.SchemaErrors as exc:
    failure_cases_df = exc.failure_cases
    display(exc.failure_cases)

# %% [markdown]
# Nothing happens because the data has no errors.
#
# Now we will start customizing the validation schema. Made another copy of it first and called it **`facilities_a10_schema.py`**. THIS IS THE FINAL SCHEMA, USE FROM NOW ON.
#
# To test, first changed one thing - to check if the `State` column equals "CA".
# Now I'll change one state to WA and see what the error report looks like.

# %%
df.loc[0,'State'] = 'WA' #change the value
df.loc[0,'State'] #check
# Out:
# 'WA'

# %%
df.head(3)
# Out:
#                                               Agency         City State  \
# 0  Los Angeles County Metropolitan Transportation...  Los Angeles    WA
# 1  Los Angeles County Metropolitan Transportation...  Los Angeles    CA
# 2  Los Angeles County Metropolitan Transportation...  Los Angeles    CA
#
#                                    Organization Type  Reporter Type Mode TOS  \
# 0  Independent Public Agency or Authority of Tran...  Full Reporter   MB  DO
# 1  Independent Public Agency or Authority of Tran...  Full Reporter   LR  DO
# 2  Independent Public Agency or Authority of Tran...  Full Reporter   MB  PT
#
#               ownerships  Under 200 Vehicles  200 to 300 Vehicles  \
# 0                  Owned                 4.0                24.52
# 1                  Owned                17.0                 0.00
# 2  Leased by PT Provider                 3.0                 0.00
#
#    Over 300 Vehicles  Heavy Maintenance Facilities  Total Facilities
# 0               0.97                          1.94             31.43
# 1               0.00                          0.00             17.00
# 2               0.00                          0.00              3.00

# %%
pd.set_option('display.max_rows',100)

from schemas.facilities_a10_schema import a10_schema

try:
    a10_schema.validate(df, lazy=True)
except pa.errors.SchemaErrors as exc:
    failure_cases_df = exc.failure_cases
    display(exc.failure_cases)
# Out:
#   schema_context column         check  check_number failure_case  index
# 0         Column  State  equal_to(CA)             0           WA      0

# %% [markdown]
# Ta-da! This is an example Pandera auto-generated error.
#
# ---

# %% [markdown]
# ### Tests to write the schema checks
# Below, we test one custom rule at a time. After testing here successfully, I added the code rule to the schema file.
#
# Also at this point I added checks to each of the `total facilities` columns to check whether they are a whole number. See the `facilities_a10_schema.py` file for the code.

# %%
# filter by agency first
agency = "Mountain Area Regional Transit Authority, dba: Mountain Transit"

df_agency = df[df['Agency']==agency]
df_agency
# Out:
#                                                               Agency  \
# 190  Mountain Area Regional Transit Authority, dba: Mountain Transit
# 197  Mountain Area Regional Transit Authority, dba: Mountain Transit
# 198  Mountain Area Regional Transit Authority, dba: Mountain Transit
#
#               City State  \
# 190  Big Bear Lake    CA
# 197  Big Bear Lake    CA
# 198  Big Bear Lake    CA
#
#                                              Organization Type  \
# 190  Independent Public Agency or Authority of Transit Service
# 197  Independent Public Agency or Authority of Transit Service
# 198  Independent Public Agency or Authority of Transit Service
#
#       Reporter Type Mode TOS ownerships  Under 200 Vehicles  \
# 190  Rural Reporter   MB  DO      Owned                 0.0
# 197  Rural Reporter   CB  DO      Owned                 0.0
# 198  Rural Reporter   DR  DO      Owned                 0.0
#
#      200 to 300 Vehicles  Over 300 Vehicles  Heavy Maintenance Facilities  \
# 190                  0.0                0.0                           0.0
# 197                  0.0                0.0                           0.0
# 198                  0.0                0.0                           0.0
#
#      Total Facilities
# 190              1.23
# 197              0.36
# 198              0.41

# %%
# df[df['Agency']==agency]['Total Facilities'].sum()
round(df[df['Agency']==agency][['Under 200 Vehicles', 
                            '200 to 300 Vehicles',
                            'Over 300 Vehicles']].sum().sum())
# Out:
# 0

# %% [markdown]
# This way we also do not use the groupby checks in Pandera

# %%
# check that sum of all total facilities per agency is a whole number.
pd.set_option('display.max_rows',100)

from schemas.facilities_a10_schema import a10_schema

try:
    a10_schema.validate(df_agency, lazy=True)
except pa.errors.SchemaErrors as exc:
    failure_cases_df = exc.failure_cases
    display(exc.failure_cases)

# %%
# Double-check the above check works, by changing the dataset
df_agency.loc[0,'Total Facilities'] = 1.55 #change the value
df_agency.loc[0,'Total Facilities'] #check
# Out:
# /var/folders/3h/9n_2y6x178l41fsp4dg802f00000gn/T/ipykernel_36003/2387290307.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_agency.loc[0,'Total Facilities'] = 1.55 #change the value
# 1.55

# %%
# retry
try:
    a10_schema.validate(df_agency, lazy=True)
except pa.errors.SchemaErrors as exc:
    failure_cases_df = exc.failure_cases
    display(exc.failure_cases)
# Out:
#    schema_context                        column         check check_number  \
# 0          Column                        Agency  not_nullable         None
# 1          Column                          City  not_nullable         None
# 2          Column                         State  not_nullable         None
# 3          Column             Organization Type  not_nullable         None
# 4          Column                 Reporter Type  not_nullable         None
# 5          Column                          Mode  not_nullable         None
# 6          Column                           TOS  not_nullable         None
# 7          Column                    ownerships  not_nullable         None
# 8          Column            Under 200 Vehicles  not_nullable         None
# 9          Column           200 to 300 Vehicles  not_nullable         None
# 10         Column             Over 300 Vehicles  not_nullable         None
# 11         Column  Heavy Maintenance Facilities  not_nullable         None
#
#    failure_case  index
# 0           NaN      0
# 1           NaN      0
# 2           NaN      0
# 3           NaN      0
# 4           NaN      0
# 5           NaN      0
# 6           NaN      0
# 7           NaN      0
# 8           NaN      0
# 9           NaN      0
# 10          NaN      0
# 11          NaN      0

# %% [markdown]
# #### Result:
# What this seems to do is return *all* cells in the offending row. Each cell is given a new row. Also, the offending column `Total Facilities` is the only one **not** shown here, which is confusing.

# %% [markdown]
# #### Conclusion:
# Faster and to instead switch to custom functions like I wrote for the A-30, and also gives greater control to format  the output as we want.

# %%
pd.set_option('display.max_colwidth',None)

# %% [markdown]
# Now testing validation against the schema with the above rules added.
# * check that each `total facilities` value is a whol number
# * check that the total facilities across all modes is > 0
# * check that the total facilities across all modes is a whole umber
# * check that the State is == 'CA'
