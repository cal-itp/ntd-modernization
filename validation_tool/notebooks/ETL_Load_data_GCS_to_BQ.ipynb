# %% [markdown]
# ### Load data
# One-time load of BlackCat 2022 NTD reports into BigQuery for bookkeeping purposes. This will not be automated as we only need to do it once.
#  Transfer from GCS bucket to BQ.
#  Python takes the excel file from GCS, loads here, copy worksheet by worksheet into BQ
#
# **First**, we must create a dataset in the BQ GUI. Here we load various tables into that dataset.
# * created `blackcat_raw` in `cal-itp-data-infra`
#
# In this notebook we create empty tables, specifying their schemas based on their column names and data types. We will then load the data into them.
#
# The code here was used to make the python script `blackcat_2022_ntdreports_toBQ.py`

# %%
import pandas as pd
from google.cloud import bigquery

# %%
GCS_FILE_PATH_RAW = "gs://calitp-ntd-report-validation/blackcat_ntd_reports_2022_raw"

def load_excel_data(sheetname):
    df = pd.read_excel(f"{GCS_FILE_PATH_RAW}/NTD_Annual_Report_Rural_2022.xlsx",
                        sheet_name=sheetname,
                        index_col=None)
    return df

# %%
# Get data from GCS
rr20_service =  load_excel_data(sheetname="Service Data")
rr20_exp_by_mode = load_excel_data(sheetname="Expenses By Mode")
rr20_rev_by_mode = load_excel_data(sheetname="Revenues By Mode")
rr20_fin = load_excel_data(sheetname="Financials - 2")
rr20_safety = load_excel_data(sheetname="Safety")
rr20_other = load_excel_data(sheetname="Other Resources")
rr20_contactinfo = load_excel_data(sheetname="Basics.Contacts")

# %%
pd.set_option('display.max_rows', None)
rr20_exp_by_mode
# Out:
#                                  OrganizationLegalName  \
# 0                  Alpine County Community Development
# 1                  Alpine County Community Development
# 2                                       Amador Transit
# 3                                       Amador Transit
# 4                                       Amador Transit
# 5                                       Amador Transit
# 6                                       Amador Transit
# 7                                       Amador Transit
# 8                            Calaveras Transit Agency
# 9                            Calaveras Transit Agency
# 10                           Calaveras Transit Agency
# 11                           Calaveras Transit Agency
# 12                                      City of Arcata
# 13                                      City of Arcata
# 14                                       City of Arvin
# 15                                       City of Arvin
# 16                                       City of Arvin
# 17                                       City of Arvin
# 18                                      City of Auburn
# 19                                      City of Auburn
# 20                                      City of Auburn
# 21                                      City of Auburn
# 22                                 City of Chowchilla
# 23                                 City of Chowchilla
# 24                                 City of Chowchilla
# 25                                 City of Chowchilla
# 26            City of Corcoran - Corcoran Area Transit
# 27            City of Corcoran - Corcoran Area Transit
# 28                                       City of Dixon
# 29                                       City of Dixon
# 30                                    City of Escalon
# 31                                    City of Escalon
# 32                                    City of Escalon
# 33                                    City of Escalon
# 34                                   City of Guadalupe
# 35                                   City of Guadalupe
# 36                                   City of Guadalupe
# 37                                   City of Guadalupe
# 38                                   City of McFarland
# 39                                   City of McFarland
# 40                                     City of Needles
# 41                                     City of Needles
# 42                                        City of Ojai
# 43                                        City of Ojai
# 44                                  City of Ridgecrest
# 45                                  City of Ridgecrest
# 46                                  City of Ridgecrest
# 47                                  City of Ridgecrest
# 48                                   City of Rio Vista
# 49                                   City of Rio Vista
# 50                                   City of Rio Vista
# 51                                   City of Rio Vista
# 52                                     City of Shafter
# 53                                     City of Shafter
# 54                                     City of Solvang
# 55                                     City of Solvang
# 56                                     City of Solvang
# 57                                     City of Solvang
# 58                                        City of Taft
# 59                                        City of Taft
# 60                                   City of Tehachapi
# 61                                   City of Tehachapi
# 62                                       City of Wasco
# 63                                       City of Wasco
# 163                            TRAX        2022           Capital
# 164                            TRAX        2022         Operating
# 165                            TRAX        2022         Operating
# 166                             NaN        2022           Capital
# 167                             NaN        2022           Capital
# 168                             NaN        2022         Operating
# 169                             NaN        2022         Operating
# 170                             NaN        2022           Capital
# 171                             NaN        2022         Operating
# 172                             TCT        2022           Capital
# 173                             TCT        2022           Capital
# 174                             TCT        2022         Operating
# 175                             TCT        2022         Operating
# 176                           YARTS        2022           Capital
# 177                           YARTS        2022         Operating
#
#                                  Mode  TotalAnnualExpensesByMode
# 0         Demand Response (DR) - (DO)                        0.0
# 1         Demand Response (DR) - (DO)                    75944.0
# 2            Commuter Bus (CB) - (DO)                        0.0
# 3         Demand Response (DR) - (DO)                        0.0
# 4    Deviated Fixed Route (DF) - (DO)                        0.0
# 5            Commuter Bus (CB) - (DO)                   208171.0
# 6         Demand Response (DR) - (DO)                   208246.0
# 7    Deviated Fixed Route (DF) - (DO)                   980081.0
# 8         Demand Response (DR) - (PT)                    50189.0
# 9    Deviated Fixed Route (DF) - (PT)                    21894.0
# 10        Demand Response (DR) - (PT)                   160056.0
# 11   Deviated Fixed Route (DF) - (PT)                   983198.0
# 12      Bus (MB) (Fixed Route) - (DO)                    40668.0
# 13      Bus (MB) (Fixed Route) - (DO)                  1125032.0
# 14        Demand Response (DR) - (DO)                        0.0
# 15   Deviated Fixed Route (DF) - (DO)                        0.0
# 16        Demand Response (DR) - (DO)                   209148.0
# 17   Deviated Fixed Route (DF) - (DO)                   644356.0
# 18        Demand Response (DR) - (DO)                    76163.0
# 19   Deviated Fixed Route (DF) - (DO)                    26748.0
# 20        Demand Response (DR) - (DO)                   334274.0
# 21   Deviated Fixed Route (DF) - (DO)                   334274.0
# 22        Demand Response (DR) - (DO)                    58531.0
# 23        Demand Response (DR) - (PT)                        NaN
# 24        Demand Response (DR) - (DO)                   470475.0
# 25        Demand Response (DR) - (PT)                        NaN
# 26        Demand Response (DR) - (DO)                        0.0
# 27        Demand Response (DR) - (DO)                   964932.0
# 28        Demand Response (DR) - (DO)                        0.0
# 29        Demand Response (DR) - (DO)                  1051331.0
# 30        Demand Response (DR) - (PT)                        0.0
# 31   Deviated Fixed Route (DF) - (PT)                    62692.0
# 32        Demand Response (DR) - (PT)                    37235.0
# 33   Deviated Fixed Route (DF) - (PT)                   145948.0
# 34      Bus (MB) (Fixed Route) - (PT)                     4441.0
# 35        Demand Response (DR) - (PT)                        0.0
# 36      Bus (MB) (Fixed Route) - (PT)                   603543.0
# 37        Demand Response (DR) - (PT)                    24378.0
# 38        Demand Response (DR) - (DO)                        0.0
# 39        Demand Response (DR) - (DO)                    58114.0
# 40   Deviated Fixed Route (DF) - (PT)                        0.0
# 41   Deviated Fixed Route (DF) - (PT)                   435885.0
# 42      Bus (MB) (Fixed Route) - (DO)                        0.0
# 43      Bus (MB) (Fixed Route) - (DO)                   733466.0
# 44        Demand Response (DR) - (DO)                   102961.0
# 45   Deviated Fixed Route (DF) - (DO)                        0.0
# 46        Demand Response (DR) - (DO)                   932161.0
# 47   Deviated Fixed Route (DF) - (DO)                   425252.0
# 48        Demand Response (DR) - (PT)                        0.0
# 49   Deviated Fixed Route (DF) - (PT)                        0.0
# 50        Demand Response (DR) - (PT)                   254386.0
# 51   Deviated Fixed Route (DF) - (PT)                   286860.0
# 52        Demand Response (DR) - (DO)                     5500.0
# 53        Demand Response (DR) - (DO)                   339578.0
# 54      Bus (MB) (Fixed Route) - (PT)                        0.0
# 55        Demand Response (DR) - (PT)                        0.0
# 56      Bus (MB) (Fixed Route) - (PT)                   792958.0
# 57        Demand Response (DR) - (PT)                   171850.0
# 58        Demand Response (DR) - (DO)                        0.0
# 59        Demand Response (DR) - (DO)                   394016.0
# 60        Demand Response (DR) - (PT)                        0.0
# 61        Demand Response (DR) - (PT)                   240065.0
# 62        Demand Response (DR) - (DO)                        0.0
# 63        Demand Response (DR) - (DO)                   390819.0
# 64        Demand Response (DR) - (DO)                        0.0
# 65        Demand Response (DR) - (DO)                  1136508.0
# 66        Demand Response (DR) - (DO)                    74828.0
# 67        Demand Response (DR) - (DO)                   376796.0
# 68      Bus (MB) (Fixed Route) - (DO)                   222010.0
# 69        Demand Response (DR) - (PT)                   131674.0
# 70      Bus (MB) (Fixed Route) - (DO)                  2876007.0
# 71        Demand Response (DR) - (PT)                  1224804.0
# 72      Bus (MB) (Fixed Route) - (PT)                        0.0
# 73           Commuter Bus (CB) - (PT)                        0.0
# 74      Bus (MB) (Fixed Route) - (PT)                   428190.0
# 75           Commuter Bus (CB) - (PT)                   246734.0
# 76      Bus (MB) (Fixed Route) - (DO)                        0.0
# 77      Bus (MB) (Fixed Route) - (DO)                  1932542.0
# 78      Bus (MB) (Fixed Route) - (PT)                  2004945.0
# 79        Demand Response (DR) - (PT)                        0.0
# 80   Deviated Fixed Route (DF) - (PT)                        NaN
# 81      Bus (MB) (Fixed Route) - (PT)                  4087027.0
# 82        Demand Response (DR) - (PT)                   388057.0
# 83   Deviated Fixed Route (DF) - (PT)                        NaN
# 84      Bus (MB) (Fixed Route) - (DO)                     4947.0
# 85           Commuter Bus (CB) - (DO)                    21447.0
# 86        Demand Response (DR) - (DO)                    66973.0
# 87      Bus (MB) (Fixed Route) - (DO)                  3526594.0
# 88           Commuter Bus (CB) - (DO)                   311888.0
# 89        Demand Response (DR) - (DO)                  1348656.0
# 90      Bus (MB) (Fixed Route) - (PT)                   743856.0
# 91        Demand Response (DR) - (PT)                   179856.0
# 92      Bus (MB) (Fixed Route) - (PT)                  1666970.0
# 93        Demand Response (DR) - (PT)                  4417583.0
# 94        Demand Response (DR) - (PT)                        0.0
# 95   Deviated Fixed Route (DF) - (PT)                        0.0
# 96        Demand Response (DR) - (PT)                   176159.0
# 97   Deviated Fixed Route (DF) - (PT)                   735889.0
# 98           Commuter Bus (CB) - (DO)                   138173.0
# 99      Intercity Service (IC) - (DO)                    12198.0
# 100          Commuter Bus (CB) - (DO)                  3414537.0
# 101     Intercity Service (IC) - (DO)                   826003.0
# 102     Bus (MB) (Fixed Route) - (PT)                   186984.0
# 103       Demand Response (DR) - (PT)                    42383.0
# 104     Bus (MB) (Fixed Route) - (PT)                  6864531.0
# 105       Demand Response (DR) - (PT)                  4677388.0
# 106     Bus (MB) (Fixed Route) - (PT)                   367868.0
# 107          Commuter Bus (CB) - (PT)                   178387.0
# 108       Demand Response (DR) - (PT)                        0.0
# 109    University Service (US) - (PT)                        NaN
# 110     Bus (MB) (Fixed Route) - (PT)                   482043.0
# 111          Commuter Bus (CB) - (PT)                   627289.0
# 112       Demand Response (DR) - (PT)                   137550.0
# 113    University Service (US) - (PT)                        NaN
# 114          Commuter Bus (CB) - (PT)                   438980.0
# 115       Demand Response (DR) - (PT)                   269053.0
# 116          Commuter Bus (CB) - (PT)                   844711.0
# 117       Demand Response (DR) - (PT)                   517726.0
# 118     Bus (MB) (Fixed Route) - (DO)                        0.0
# 119       Demand Response (DR) - (DO)                        0.0
# 120  Deviated Fixed Route (DF) - (DO)                        0.0
# 121     Bus (MB) (Fixed Route) - (DO)                  4697550.0
# 122       Demand Response (DR) - (DO)                   815531.0
# 123  Deviated Fixed Route (DF) - (DO)                   174025.0
# 124     Bus (MB) (Fixed Route) - (PT)                        0.0
# 125       Demand Response (DR) - (PT)                        0.0
# 126     Bus (MB) (Fixed Route) - (PT)                   290045.0
# 127       Demand Response (DR) - (PT)                   218699.0
# 128          Commuter Bus (CB) - (DO)                   100818.0
# 129       Demand Response (DR) - (DO)                   175776.0
# 130  Deviated Fixed Route (DF) - (DO)                   420471.0
# 131     Intercity Service (IC) - (DO)                   323860.0
# 132          Commuter Bus (CB) - (DO)                   394884.0
# 133       Demand Response (DR) - (DO)                   688474.0
# 134  Deviated Fixed Route (DF) - (DO)                  1646892.0
# 135     Intercity Service (IC) - (DO)                  1268486.0
# 136     Bus (MB) (Fixed Route) - (DO)                   970471.0
# 137          Commuter Bus (CB) - (DO)                   107461.0
# 138       Demand Response (DR) - (DO)                   107461.0
# 139     Bus (MB) (Fixed Route) - (DO)                  2882009.0
# 140          Commuter Bus (CB) - (DO)                   455684.0
# 141       Demand Response (DR) - (DO)                   800499.0
# 142          Commuter Bus (CB) - (PT)                        0.0
# 143       Demand Response (DR) - (PT)                        NaN
# 144  Deviated Fixed Route (DF) - (PT)                        0.0
# 145          Commuter Bus (CB) - (PT)                   328825.0
# 146       Demand Response (DR) - (PT)                        NaN
# 147  Deviated Fixed Route (DF) - (PT)                   831812.0
# 148  Deviated Fixed Route (DF) - (PT)                        0.0
# 149  Deviated Fixed Route (DF) - (PT)                   891232.0
# 150     Bus (MB) (Fixed Route) - (PT)                   112138.0
# 151       Demand Response (DR) - (PT)                        0.0
# 152     Bus (MB) (Fixed Route) - (PT)                  1354820.0
# 153       Demand Response (DR) - (PT)                   194824.0
# 154     Bus (MB) (Fixed Route) - (PT)                        0.0
# 155          Commuter Bus (CB) - (PT)                        0.0
# 156       Demand Response (DR) - (PT)                    12469.0
# 157     Bus (MB) (Fixed Route) - (PT)                   114268.0
# 158          Commuter Bus (CB) - (PT)                   670678.0
# 159       Demand Response (DR) - (PT)                  1596511.0
# 160       Demand Response (DR) - (PT)                        0.0
# 161       Demand Response (DR) - (PT)                   163221.0
# 162     Bus (MB) (Fixed Route) - (PT)                        0.0
# 163       Demand Response (DR) - (PT)                        0.0
# 164     Bus (MB) (Fixed Route) - (PT)                  1470471.0
# 165       Demand Response (DR) - (PT)                   559003.0
# 166     Bus (MB) (Fixed Route) - (PT)                        0.0
# 167       Demand Response (DR) - (PT)                        0.0
# 168     Bus (MB) (Fixed Route) - (PT)                   696369.0
# 169       Demand Response (DR) - (PT)                   410181.0
# 170     Intercity Service (IC) - (DO)                        0.0
# 171     Intercity Service (IC) - (DO)                   711792.0
# 172     Bus (MB) (Fixed Route) - (PT)                    58640.0
# 173       Demand Response (DR) - (PT)                   156040.0
# 174     Bus (MB) (Fixed Route) - (PT)                   835965.0
# 175       Demand Response (DR) - (PT)                  1557835.0
# 176     Bus (MB) (Fixed Route) - (PT)                     9835.0
# 177     Bus (MB) (Fixed Route) - (PT)                  3571267.0

# %%
## Load into "blackcat_raw" BQ tables - we do *not* modify at all from the original here - 
# ...when we do, those are saved into "_parsed" BQ tables
# Construct a BigQuery client object.
client = bigquery.Client()

# %%
# Set table_id to the ID of the table to create.
#----------- Service
table_id = "cal-itp-data-infra.blackcat_raw.2022_rr20_service"
# Remove spaces and slashes from cols - they are illegal in BQ.
rr20_service.columns = rr20_service.columns.str.replace(' ', '')
rr20_service.columns = rr20_service.columns.str.replace('/', '_')

columns = rr20_service.columns.values
columns
# Out:
# array(['OrganizationLegalName', 'CommonName_Acronym_DBA', 'FiscalYear',
#        'Mode', 'AnnualVRM', 'AnnualVRH', 'AnnualUPT', 'SponsoredUPT',
#        'VOMX'], dtype=object)

# %%
########### Make dict of colname: BQ type
# If col is object, it's string. If all col % 1 == 0, int
# if col is numeric but not % 1 == 0, float

#------ testing
rr20_service.dtypes
# rr20_service['Annual VRM'].dtypes
# all(x.is_integer() for x in rr20_service['Annual VRM'])
# Out:
# OrganizationLegalName      object
# CommonName_Acronym_DBA     object
# FiscalYear                  int64
# Mode                       object
# AnnualVRM                 float64
# AnnualVRH                 float64
# AnnualUPT                 float64
# SponsoredUPT              float64
# VOMX                      float64
# dtype: object

# %%
schema_dict = {}
for x in columns:
    if rr20_service[x].dtypes == 'float64':
        schema_dict[x] = "FLOAT64"
    elif rr20_service[x].dtypes == 'int64':
        schema_dict[x] = "INT64"
    elif rr20_service[x].dtypes == 'object':
        schema_dict[x] =  "STRING"

# %%
schema_dict
# Out:
# {'OrganizationLegalName': 'STRING',
#  'CommonName_Acronym_DBA': 'STRING',
#  'FiscalYear': 'INT64',
#  'Mode': 'STRING',
#  'AnnualVRM': 'FLOAT64',
#  'AnnualVRH': 'FLOAT64',
#  'AnnualUPT': 'FLOAT64',
#  'SponsoredUPT': 'FLOAT64',
#  'VOMX': 'FLOAT64'}

# %%
schema = []
for k, v in schema_dict.items():
    schema.append(bigquery.SchemaField(k, v, mode="REQUIRED"))

# %%
schema
# Out:
# [SchemaField('OrganizationLegalName', 'STRING', 'REQUIRED', None, None, (), None),
#  SchemaField('CommonName_Acronym_DBA', 'STRING', 'REQUIRED', None, None, (), None),
#  SchemaField('FiscalYear', 'INT64', 'REQUIRED', None, None, (), None),
#  SchemaField('Mode', 'STRING', 'REQUIRED', None, None, (), None),
#  SchemaField('AnnualVRM', 'FLOAT64', 'REQUIRED', None, None, (), None),
#  SchemaField('AnnualVRH', 'FLOAT64', 'REQUIRED', None, None, (), None),
#  SchemaField('AnnualUPT', 'FLOAT64', 'REQUIRED', None, None, (), None),
#  SchemaField('SponsoredUPT', 'FLOAT64', 'REQUIRED', None, None, (), None),
#  SchemaField('VOMX', 'FLOAT64', 'REQUIRED', None, None, (), None)]

# %%
# # from BQ example page:
# schema = [
#         bigquery.SchemaField(x, "STRING", mode="REQUIRED"),
#         bigquery.SchemaField("age", "INTEGER", mode="REQUIRED"),
#     ]

# %%
table = bigquery.Table(table_id, schema=schema)

# %%
table
# Out:
# Table(TableReference(DatasetReference('cal-itp-data-infra', 'blackcat_raw'), '2022_rr20_service'))

# %%
table = client.create_table(table)  # Make an API request.
# print(
#     "Created table {}.{}.{}".format(table.project, table.dataset_id, table.table_id)
# )

# %% [markdown]
# ## Make function to do the above actions for all tables

# %%
# tables_to_load = [rr20_service, rr20_exp_by_mode, rr20_rev_by_mode,
#                  rr20_fin, rr20_safety, rr20_other, rr20_contactinfo]

dfdict = {"rr20_exp_by_mode": rr20_exp_by_mode, 
          "rr20_rev_by_mode": rr20_rev_by_mode,
          "rr20_fin": rr20_fin, 
          "rr20_safety": rr20_safety, 
          "rr20_other": rr20_other, 
          "rr20_contactinfo": rr20_contactinfo}

# %%
for k,v in dfdict.items():
    table_id = f"cal-itp-data-infra.blackcat_raw.2022_{k}"
    # Remove spaces and slashes from col names 
    v.columns = v.columns.str.replace(' ', '')
    v.columns = v.columns.str.replace('/', '_')
    columns = v.columns.values
    
    schema_dict = {}
    for x in columns:
        if v[x].dtypes == 'float64':
            schema_dict[x] = "FLOAT64"
        elif v[x].dtypes == 'int64':
            schema_dict[x] = "INT64"
        elif v[x].dtypes == 'object':
            schema_dict[x] =  "STRING"
    
    schema = []
    for k, v in schema_dict.items():
        schema.append(bigquery.SchemaField(k, v)) 
    
    table = bigquery.Table(table_id, schema=schema)
    table = client.create_table(table)
    print(f"Created table {table.project}.{table.dataset_id}.{table_id}")
# Out:
# Created table cal-itp-data-infra.blackcat_raw.cal-itp-data-infra.blackcat_raw.2022_rr20_exp_by_mode
# Created table cal-itp-data-infra.blackcat_raw.cal-itp-data-infra.blackcat_raw.2022_rr20_rev_by_mode
# Created table cal-itp-data-infra.blackcat_raw.cal-itp-data-infra.blackcat_raw.2022_rr20_fin
# Created table cal-itp-data-infra.blackcat_raw.cal-itp-data-infra.blackcat_raw.2022_rr20_safety
# Created table cal-itp-data-infra.blackcat_raw.cal-itp-data-infra.blackcat_raw.2022_rr20_other
# Created table cal-itp-data-infra.blackcat_raw.cal-itp-data-infra.blackcat_raw.2022_rr20_contactinfo

# %% [markdown]
# Note: I had to delete these tables because I forgot this part:  ```schema = []
#     for k, v in schema_dict.items():
#         schema.append(bigquery.SchemaField(k, v, mode="REQUIRED"))```
#
# and they were made with identical schemas. So I did **not** rerun it, but rolled it all into the file `blackcat_2022_ntdreports_toBQ.py` to be made **and loaded** in a for loop

# %% [markdown]
# ### Load data into newly created tables

# %%
## Try for rr-20 service without specifying the schema

table_id = "cal-itp-data-infra.blackcat_raw.2022_rr20_service"

job_service = client.load_table_from_dataframe(
    rr20_service, table_id
)  
job_service.result()  # Wait for the job to complete.
# Out:
# LoadJob<project=cal-itp-data-infra, location=us-west2, id=9703c92b-bd3e-47b1-9e7c-2efbd8140f81>

# %%
table = client.get_table(table_id)  # Make an API request.

# %%
print(
    "Loaded {} rows and {} columns to {}".format(
        table.num_rows, len(table.schema), table_id))
# Out:
# Loaded 89 rows and 9 columns to cal-itp-data-infra.blackcat_raw.2022_rr20_service
